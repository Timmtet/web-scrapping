# %% [markdown]
# ### First task to to know how to obtain the URL of all the different pages

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.jumia.com.ng/phones-tablets/'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')

np = soup.find('div', class_ ="pg-w -ptm -pbxl")
np1 = np.find_all('a')[5]
np2= np1.get('href')
np3= 'https://www.jumia.com.ng/phones-tablets/' +np2
print(np3)
# Out:
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=2#catalog-listing

# %% [raw]
# url = 'https://www.jumia.com.ng/phones-tablets/'
# response = requests.get(url)
#
# soup = BeautifulSoup(response.text, 'lxml')
#
# while True:
#     np = soup.find('div', class_ ="pg-w -ptm -pbxl")
#     np1 = np.find_all('a')[5]
#     np2= np1.get('href')
#     np3= 'https://www.jumia.com.ng/phones-tablets/' +np2
#     print(np3)
#
#     url= np3
#     response = requests.get(url)
#     soup =BeautifulSoup(response.text, 'lxml')

# %%
while True:
    np = soup.find('div', class_ ="pg-w -ptm -pbxl")
    np1 = np.find_all('a')[5]
    np2= np1.get('href')
    np3= 'https://www.jumia.com.ng/phones-tablets/' +np2
    print(np3)
    
    url= np3 
    response = requests.get(url)
    soup =BeautifulSoup(response.text, 'lxml')
# Out:
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=2#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=3#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=4#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=5#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=6#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=7#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=8#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=9#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=10#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=11#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=12#catalog-listing
# https://www.jumia.com.ng/phones-tablets//phones-tablets/?page=13#catalog-listing
# ...

# %% [markdown]
# ### Now, we will extract data from the first page only

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.jumia.com.ng/phones-tablets/'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')


nam = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
name = nam.find_all('div', class_ = 'info')

all_names = []
for i in name:
    names = i.find('h3', class_ = 'name')
    all_names.append(names.text)
#print(all_names)

pric = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
price = pric.find_all('div', class_ = 'info')

all_price = []
for j in price:
    prices = j.find('div', class_ = 'prc')
    all_price.append(prices.text)
#print(all_price) 

df = pd.DataFrame({'product name': all_names, 'product price': all_price})
df
# Out:
#                                          product name product price
# 0     Huawei Nova 9 Full Glue Curved Screen Protector       ₦ 7,000
# 1                Samsung Clear View Cover A03S GALAXY       ₦ 3,000
# 2      Oraimo 20000mAh Power Charging Bank OPB-P208DN       ₦ 9,980
# 3   itel 20000mAh Dual Output Fast Charging Power ...       ₦ 8,740
# 4   XIAOMI Redmi Note 12 6.67'' 8GB 128GB ROM Andr...     ₦ 150,000
# 5   Ace Elec F9 Wireless Fingerprint Touch Bluetoo...       ₦ 2,900
# 6                 Oraimo Power-Bank OPB-P208DN 20KmAh       ₦ 9,980
# 7   Oraimo 27000mAh Massive Portable Power Chargin...      ₦ 17,960
# 8   itel 10000MAh Star100 Fast Charging Powerbank ...       ₦ 5,500
# 9   Samsung Galaxy A03 Core Android 11 - 6.5 Inche...      ₦ 57,680
# 10  Oraimo Power-Bank 10000mAh Ultra-Slim With Fas...       ₦ 7,510
# 11  XIAOMI A1 Plus, 6.52" 4G LTE, 2GB/32GB Memory,...      ₦ 52,530
# 12      Tws Wireless Bluetooth Headsets Earphones I12       ₦ 2,599
# ...

# %%
url = 'https://www.jumia.com.ng/phones-tablets/'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')

all_names = []
all_price = []

nam = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
name = nam.find_all('div', class_ = 'info')


for i in name:
    names = i.find('h3', class_ = 'name')
    all_names.append(names.text)

pric = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
price = pric.find_all('div', class_ = 'info')


for j in price:
    prices = j.find('div', class_ = 'prc')
    all_price.append(prices.text)


for i in range(10):
    np = soup.find('div', class_ ="pg-w -ptm -pbxl")
    np1 = np.find_all('a')[5]
    np2= np1.get('href')
    np3= 'https://www.jumia.com.ng/phones-tablets/' +np2
    #print(np3)
    
    url= np3 
    response = requests.get(url)
    soup =BeautifulSoup(response.text, 'lxml')
    
    url = 'https://www.jumia.com.ng/phones-tablets/'
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'lxml')


    nam = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
    name = nam.find_all('div', class_ = 'info')

    
    for i in name:
        names = i.find('h3', class_ = 'name')
        all_names.append(names.text)
    #print(all_names)

    pric = soup.find('div',class_="-paxs row _no-g _4cl-3cm-shs")
    price = pric.find_all('div', class_ = 'info')

    
    for j in price:
        prices = j.find('div', class_ = 'prc')
        all_price.append(prices.text)
    #print(all_price) 

df = pd.DataFrame({'product name': all_names, 'product price': all_price})
df
# Out:
#                                           product name product price
# 0      Huawei Nova 9 Full Glue Curved Screen Protector       ₦ 7,000
# 1                 Samsung Clear View Cover A03S GALAXY       ₦ 3,000
# 2       Oraimo 20000mAh Power Charging Bank OPB-P208DN       ₦ 9,980
# 3    XIAOMI Redmi Note 12 6.67'' 8GB 128GB ROM Andr...     ₦ 150,000
# 4    itel 20000mAh Dual Output Fast Charging Power ...       ₦ 8,740
# ..                                                 ...           ...
# 445  Tecno Pop 5 Go Bd1 - 5.71", 16GB ROM 1GB RAM-5...      ₦ 40,070
# 446  Apple IPhone 14 Pro Max 6.7" 256GB - Dual Nano...   ₦ 1,150,000
# 447  Y30 Wireless Blutooth 5.0 Earphone Headset In-...       ₦ 2,290
# 448  Smart Watch Full Touch Screen Watch - For Andr...       ₦ 5,790
# 449  F9 Fingerprint Touch Stereo Noise Cancelling H...       ₦ 3,960
#
# [450 rows x 2 columns]

# %%
df.tail(10)
# Out:
#                                           product name product price
# 440  Transparent 50000 Mah Super Fast Power Bank Ca...      ₦ 24,700
# 441  Fingerprint Touch 5.0 Earphone Wireless HIFI S...       ₦ 2,970
# 442  Tecno Sonic 1 Fireboy DML Wireless Bluetooth E...       ₦ 9,998
# 443  Oraimo FreePods 4 Active Noise Cancellation Ea...      ₦ 20,430
# 444  Oraimo 27000Mah Portable Power Banks Fast Char...      ₦ 17,100
# 445  Tecno Pop 5 Go Bd1 - 5.71", 16GB ROM 1GB RAM-5...      ₦ 40,070
# 446  Apple IPhone 14 Pro Max 6.7" 256GB - Dual Nano...   ₦ 1,150,000
# 447  Y30 Wireless Blutooth 5.0 Earphone Headset In-...       ₦ 2,290
# 448  Smart Watch Full Touch Screen Watch - For Andr...       ₦ 5,790
# 449  F9 Fingerprint Touch Stereo Noise Cancelling H...       ₦ 3,960
